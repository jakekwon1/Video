# %%
import sys, cv2, time
import numpy as np

# %%
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print('cam  not found')
    sys.exit()
    
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h= int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
fourcc = cv2.VideoWriter_fourcc(*'DIVX')

out = cv2.VideoWriter('fig/output.avi',fourcc, fps,(w,h), isColor=False)


while True:
    ret, frame = cap.read()
    if not ret:
        print('frame not found')
        break
    
    edge = cv2.Canny(frame, 80,120)
    
    out.write(edge)
    
    cv2.imshow('frame', edge)
    
    if cv2.waitKey(20) == 27:
        break


out.release()
cap.release()
cv2.destroyAllWindows()

# %%
img = np.full((600, 1200,3), 255, np.uint8)

cv2.line(img, (50,50), (300,100), (0,0, 255), 5, cv2.LINE_AA)
cv2.arrowedLine(img, (300,100), (300, 200), (255, 0,0),5, cv2.LINE_AA)
cv2.rectangle(img, (400,100), (600,300), (0,255,0),10 ,cv2.LINE_AA)
cv2.rectangle(img, (400,100), (600,300), (0,255,0),-1 ,cv2.LINE_AA)
cv2.circle(img, (400,300), 100, (21,66,35), -1 , cv2.LINE_AA)
cv2.ellipse(img, (800, 300), (50, 200), 10, 0, 360, (0,0,255), 10, cv2.LINE_AA )
cv2.putText(img, 'Person: 89%', (800,100), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,0,255),1)

pts = np.array([[250,200], [400,200], [500,400], [200,400]])


cv2.polylines(img, [pts], True, (255,0,0), 2, cv2.LINE_AA)


cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img = cv2.imread('fig/puppy.bmp', 0)

image = img.copy()

cv2.imshow('img', img)

while True:
    key = cv2.waitKey()
    
    if key == 27 or key == ord('q'):
        break
    
    elif key == ord('e'):
        image = cv2.Canny(image, 50 ,100)
        cv2.imshow('img', image)
    
    elif key == ord('i'):
        image = 255 - image
        cv2.imshow('img', image)

    elif key == ord('r'):
        image = img.copy()
        cv2.imshow('img', image)
        
    elif key == ord('s'):
        print('image saved')
        cv2.imwrite('/fig/save.png',frame)
    
    
# cv2.imshow('img', img)

# cv2.waitKey()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print('cam  not found')
    sys.exit()
    
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h= int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
fourcc = cv2.VideoWriter_fourcc(*'DIVX')

out = cv2.VideoWriter('fig/output.avi',fourcc, fps,(w,h), isColor=False)
c_frame = frame.copy()

while True:
    ret, frame = cap.read()

    c_frame = frame.copy()
    key = cv2.waitKey(20)
    if not ret:
        print('frame not found')
        break
    
    edge = cv2.Canny(frame, 80,120)
    
    out.write(edge)
    
    cv2.imshow('frame', c_frame)
    
    if key == 27 or key == ord('q'):
        break
    
    elif key == ord('e'):
        c_frame = cv2.Canny(c_frame, 50 ,100)
        cv2.imshow('frame',c_frame)
    
    elif key == ord('i'):
        c_frame = 255 - c_frame   # 색 반전
        cv2.imshow('frame', c_frame)

    elif key == ord('r'):
        c_frame = frame.copy()
        cv2.imshow('frame', c_frame)
        
    elif key == ord('s'):
        print('c_frame saved')
        cv2.imwrite('fig/save.png', c_frame)
    
    elif key == ord('f'):
        cv2.imshow('frame',cv2.flip(c_frame, 1))
        
        
out.release()
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print('cam  not found')
    sys.exit()

# cv2.imshow('frame', frame)

f_key = False
e_key = True
i_key = False
b_key = False     # 스위치 설정

while True:
    ret, frame = cap.read()
    # frame = frame.copy()
    key = cv2.waitKey(20)
    if not ret:
        print('frame not found')
        break
    
    # cv2.imshow('frame', frame) # 실행 즉시 영상 뜸
    
    if f_key:
        frame = cv2.flip(frame, 1)

    if b_key:
        frame = cv2.flip(frame, 0)    

    if e_key:
        frame = cv2.Canny(frame, 50, 100)
    
    if i_key:
        frame = 255 - frame
    
    cv2.imshow('frame', frame)  # 변경된 설정 적용 후 출력
    
    if key == 27 or key == ord('q'):
        break
    
    elif key == ord('e'):   # 스위치 변경 트리거
        e_key = not e_key
    
    elif key == ord('f'):
        f_key = not f_key
        
    elif key == ord('i'):
        i_key = not i_key
        
    elif key == ord('b'):
        b_key = not b_key
        
out.release()
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 마우스 사용하여 명령어 입력

# %%
def click(event,x,y,flags,param):
    global oldx, oldy
    
    if event == cv2.EVENT_LBUTTONDOWN:
        oldx, oldy = x,y

    # elif event == cv2.EVENT_LBUTTONUP:
    #     print(x,y)

    elif event == cv2.EVENT_MOUSEMOVE:
        if flags == cv2.EVENT_FLAG_LBUTTON:
            cv2.line(img, (oldx, oldy), (x,y), (0,0,0), 5,cv2.LINE_AA)
            cv2.imshow('img', img)
            oldx, oldy = x,y

# %%
img = np.ones((600,600,3),np.uint8)*255
img1 = img.copy()

cv2.namedWindow('img')
cv2.setMouseCallback('img', click)

while True:
    cv2.imshow('img',img1)
    key = cv2.waitKey()
    if key == 27 or key == ord('q'):
        break    
    
    if key == ord('s'):
        print('image saved')
        cv2.imwrite('fig/save.png', img)
    
    elif key == ord('c'):
        img = img1.copy()
        cv2.imshow('img',img)

cv2.destroyAllWindows()
# Out:
# image saved

# %%
def adj(pos):
    # img[:] = (img1*(pos/255.)).astype(np.uint8)  # 넘파이는 clipping 적용 안됨
    img[:] = np.clip(img1*(pos/128.),0, 255).astype(np.uint8) # 넘파이 사용시 np.clip. 함수 사용
    # img[:] = cv2.add(img1,pos) # cv2 는 clipping 자동 적용
    cv2.imshow('img', img)

img = cv2.imread('fig/puppy.bmp',0)
img1 = img.copy()
# img = cv2.add(img, 20)

cv2.imshow('img', img)

cv2.createTrackbar('level','img', 0, 255, adj)  # img 에 숫자 바 하나 만들고 그 바가 영향 끼치는 "것" 을 정의해 놓음

cv2.waitKey()
cv2.destroyAllWindows()

# %%
def bar(pos):
    img[:] = (img1*(pos/255.)).astype('uint8')
    cv2.imshow('img', img)

img = cv2.imread('fig/field.bmp', 0)

if img is None:
    print('img not found')
    sys.exit()

img1 = img.copy()

cv2.imshow('img', img)
cv2.createTrackbar('level','img',0, 255, bar)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
def click(event, x,y,flags, param):
    global oldx,oldy
    
    if event == cv2.EVENT_LBUTTONDOWN:
        oldx, oldy= x,y
    
    elif event == cv2.EVENT_MOUSEMOVE:
        if flags == cv2.EVENT_FLAG_LBUTTON:
            cv2.line(img, (oldx,oldy), (x,y),(0,0,255), 5,cv2.LINE_AA)
            cv2.imshow('img',img)
            oldx,oldy = x,y

img = np.ones((600,600,3),np.uint8)* 255
cv2.imshow('img', img)
cv2.setMouseCallback('img', click)


while True:
    key = cv2.waitKey()
    if key == 27 or key == ord('q'):
        break
    elif key == ord('s'):
        print('img saved')
        cv2.imwrite('img.pug', img)


cv2.waitKey()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    prnit('cam not found')
    sys.exit()
    
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
fourcc = int(cap.get(cv2.CAP_PROP_FOURCC))

out = cv2.VideoWriter('fig/output.avi', fourcc, fps, (w,h))

while True:
    ret, frame = cap.read()
#     key = cv2.waitKey()
    
#     if not ret:
#         print('frame not found')
#         break
#     cv2.imshow('frame', frame)
    
#     out.write(frame)
#     if key == 27 or key == ord('q'):
#         break
    
# cap.release()
out.release()
cv2.destroyAllWindows()

# %%
img = np.full((600,1200,3), (255,255,0),np.uint8)

cv2.line(img, (100,100), (300,200), (0,0,255), 5, cv2.LINE_AA)
cv2.arrowedLine(img, (300, 200), (300,400), (0,255,0), 5, cv2.LINE_AA)

cv2.rectangle( img, (100,400), (200, 500), (255,0,0), 4, cv2.LINE_AA)
cv2.rectangle( img, (120,420,60,60), (0,0,255), -1)

cv2.circle(img, (600,300), 50, (123,123,123) ,5 , cv2.LINE_AA)
cv2.ellipse(img, (800, 300), (50,200), 0, 180, 360, (128,128,0), -1,cv2.LINE_AA)

cv2.putText(img, "Let's Go Home", (800,100), cv2.FONT_HERSHEY_SCRIPT_COMPLEX,2, (0,255,255), 2, cv2.LINE_AA)
pts = np.array([[250,200],[350,300],[ 350, 200], [250, 300]])
cv2.polylines(img, [pts],True, (255,0,0), 5,cv2.LINE_AA)

cv2.imshow('img', img)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
# 명령어가 걸리는 시간 측정


img = cv2.imread('fig/puppy.bmp',0)

t1=time.time()

for _ in range(10):
    img = cv2.GaussianBlur(img, (0,0),2)
    
t2 =time.time()

cv2.imshow('img',img)
print('time = ', round((t2-t1)*100,3), 'ms')

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# time =  1.048 ms
